# %% [markdown]
# <a href="https://colab.research.google.com/github/zeyneptaskinnn/webOrumcegi/blob/main/testBeautifulSoap4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# Web Sayfasını Çek
url  = "https://madran.net" # İstediğiniz Web sitesinin URL'sini girin
response = requests.get(url)
html_icerigi = response.content

# BeautifulSoup nesnesi oluştur
soup = BeautifulSoup(html_icerigi, "html.parser")

# Başlığı bul ve yazdır
baslik = soup.find("title").text
print("Başlık:", baslik)

# Tüm bağlantıları bul ve yazdır
linkler = soup.find_all("a")
for link in linkler:
  print("Bağlantı:", link.get("href"))
# Out:
# Başlık: R. Orçun Madran – Akademisyen | Aktivist | Triatlet
# Bağlantı: #content
# Bağlantı: https://madran.net/
# Bağlantı: #search-container
# Bağlantı: https://madran.net/
# Bağlantı: https://twitter.com/orcunmadran
# Bağlantı: https://www.youtube.com/orcunmadran
# Bağlantı: https://www.instagram.com/orcunmadran/
# Bağlantı: https://www.facebook.com/orcunmadran/
# Bağlantı: https://www.linkedin.com/in/omadran/
# Bağlantı: https://www.strava.com/athletes/8784393
# Bağlantı: http://www.madran.net
# Bağlantı: https://madran.net/orcun_madran/
# Bağlantı: #
# Bağlantı: https://madran.net/akademik-yayinlar/
# Bağlantı: https://podcasters.spotify.com/pod/show/orcunmadran
# Bağlantı: https://madran.net/category/akademiden-notlar/
# Bağlantı: https://podcasters.spotify.com/pod/show/akademiden-notlar
# Bağlantı: #
# Bağlantı: https://madran.net/bby-162-programlama-ve-algoritmalar/
# Bağlantı: https://madran.net/bby-261-ileri-programlama/
# Bağlantı: https://madran.net/bby-262-web-tasarimi/
# ...
